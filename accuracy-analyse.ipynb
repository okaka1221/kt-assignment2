# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
import operator
import gc
import time

# %%
x = [200, 300, 500, 800, 1000, 1500, 2000, 2500, 3000, 4000]
y_lgbm = [
    0.8365553199145568,
    0.8439818394799905,
    0.8452374572209504,
    0.8508341436151072,
    0.8544555289289734,
    0.8553972422346934,
    0.8514849211027998,
    0.8495632134626722,
    0.849547901051197,
    0.8532458484224388
] 
y_nn = [
    0.8392579605399156,
    0.849792899634799,
    0.8523424161454066,
    0.8645234394738656,
    0.8704493427147374,
    0.8770489920605147,
    0.8821097440530422,
    0.8847205102095503,
    0.8870403405480312,
    0.8875609625381853
]

# %%
plt.plot(x, y_lgbm, marker='o', label='LightGBM')
plt.plot(x, y_nn, marker='o', label='NN')
plt.xlabel('The number of best words')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('result-on-training')

# %%
x_lgbm = [500, 800, 1000, 1500]
y_lgbm = [0.84706, 0.84524, 0.84716, 0.84767]
x_nn = [200, 500, 1000]
y_nn = [0.82189, 0.83624, 0.82745]

# %%
plt.plot(x_lgbm, y_lgbm, marker='o', label='LightGBM')
plt.plot(x_nn, y_nn, marker='o', label='NN')
plt.xlabel('The number of best words')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('result-on-kaggle')
